# %%
# plot the results of analysis

import sys
import os
repo_root = os.path.abspath("..")
sys.path.append(os.path.join(repo_root, "src"))

from data_utils import RecipeAnalysis

data_path = os.path.join(repo_root, "data", "raw", "epi_r.csv")
ra = RecipeAnalysis(data_path)
ra.preprocess()
ra.run_lasso(target_col='rating')

# Plot top positive and negative tags
ra.plot_top_tags(top_n=10)
